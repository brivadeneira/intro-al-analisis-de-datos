# %% [markdown]
# # Data cleaning  Exercises

# %%
import pandas as pd

# %% [markdown]
# ## rename()

# %% [markdown]
# ¡La documentación es tu amiga! [rename](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html)

# %% [markdown]
# ### Sincrónicos

# %% [markdown]
# * Crear un DataFrame a partir del archivo `./datasets/sample-wine-data.csv`
#
# > El archivo es una pequeña muestra del dataset [wine-reviews](https://www.kaggle.com/datasets/zynicide/wine-reviews) que contiene información sobre reviews de vinos, incluyendo variedad, geolocalización, vinería, precio y descripción.

# %% [markdown]
# * Las columnas `region_1` y `region_2` tienen nombres poco descriptivos, *renomblarlas* como `region` y `locate` respectivamente.

# %% [markdown]
# * Guardar el dataset en un archivo `.csv` junto con los demás datasets

# %% [markdown]
# ### Estándares para nombrar columnas

# %% [markdown]
# ![image.png](attachment:e01c9706-f2d2-45f4-8f8e-a680186b6a65.png)![image.png](attachment:1b8f2092-8a69-4a5a-90fa-b48c644cc12f.png)

# %% [markdown]
# > En general *se tiende* a usar `snake case` dado que coincide con la convención recomendada en la PEP8, y es sencillo acceder a las columnas como si fueran atributos del DataFrame.

# %% [markdown]
# ### Asincrónicos

# %% [markdown]
# * Explorar el directorio `datasets` y renombrar las columnas que se consideren necesarias **durante el import**.
# * Exportar los DataFrames corregidos en nuevos archivos `.csv`.

# %% [markdown]
# * Dado el siguiente DataFrame (reducido):

# %%
employees_sample = {
    "Department": {0: "DPT", 1: "868", 2: "868"},
    "Name": {0: "NAME", 1: "B J SANDIFORD", 2: "C A WIGFALL"},
    "Address": {
        0: "ADDRESS",
        1: "DEPARTMENT OF CITYWIDE ADM",
        2: "DEPARTMENT OF CITYWIDE ADM",
    },
    "Title": {0: "TTL #", 1: "12702", 2: "12702"},
    "Pay Class": {0: "PC", 1: "X", 2: "X"},
    "Salary Rate": {0: "SAL-RATE", 1: "$5.00", 2: "$5.00"},
}

df = pd.DataFrame(employees_sample)

df

# %% [markdown]
# * Realizar las modificaciones necesarias para delimitar `index`, `header` y `data` correctamente.

# %% [markdown]
# * Completar la siguiente tabla:
#
# | Column name 	| Data classification 	|
# |------------:	|--------------------:	|
# |  Department 	|                     	|
# |        Name 	|                     	|
# |     Address 	|                     	|
# |       Title 	|                     	|
# |   Pay Class 	| categórico, nominal 	|
# | Salary Rate 	|                     	|
#
# > [herramienta online de generación de tablas en Markdown](https://www.tablesgenerator.com/markdown_tables#)

# %% [markdown]
# * Renombrar las columnas del siguiente DataFrame en base a la [tabla original](https://es.wikipedia.org/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos).

# %%
df = pd.read_html(
    "https://es.wikipedia.org/wiki/Anexo:Medallero_de_los_Juegos_Ol%C3%ADmpicos",
    index_col=[0],
)[2]

df

# %% [markdown]
# * ¿Cómo está conformado el Index?

# %% [markdown]
# * Clasificar los datos de las columnas

# %% [markdown]
# ## drop_duplicates()
#
# ¡La documentación es tu amiga! [drop_duplicates](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html)

# %% [markdown]
# ### Sincrónicos

# %% [markdown]
# * Dado el siguiente DataFrame con algunos datos de visitas de perros al veterinario:

# %%
dogs_visits = {
    "date": {
        0: "2018-09-02",
        1: "2019-03-13",
        2: "2019-03-19",
        3: "2018-10-02",
        4: "2018-01-17",
        5: "2019-10-19",
        6: "2019-05-01",
        7: "2019-06-07",
        8: "2019-03-30",
        9: "2019-01-04",
        10: "2019-04-22",
        11: "2018-08-17",
        12: "2019-08-19",
        13: "2019-09-30",
        14: "2019-11-29",
    },
    "name": {
        0: "Bella",
        1: "Max",
        2: "Charlie",
        3: "Bella",
        4: "Stella",
        5: "Lucy",
        6: "Max",
        7: "Max",
        8: "Cooper",
        9: "Bernie",
        10: "Charlie",
        11: "Stella",
        12: "Charlie",
        13: "Cooper",
        14: "Lucy",
    },
    "breed": {
        0: "Labrador",
        1: "Chow Chow",
        2: "Poodle",
        3: "Labrador",
        4: "Chihuahua",
        5: "Chow Chow",
        6: "Chow Chow",
        7: "Labrador",
        8: "Schnauzer",
        9: "St. Bernard",
        10: "Poodle",
        11: "Labrador",
        12: "Chihuahua",
        13: "Chow Chow",
        14: "Chow Chow",
    },
    "weight_kg": {
        0: 24.87,
        1: 24.13,
        2: 24.95,
        3: 33.72,
        4: 1.51,
        5: 24.07,
        6: 31.25,
        7: 28.35,
        8: 16.91,
        9: 74.98,
        10: 25.37,
        11: 23.55,
        12: 2.95,
        13: 25.16,
        14: 24.19,
    },
}
df = pd.DataFrame(dogs_visits)

df

# %% [markdown]
# * ¿Cómo está conformado el index?

# %% [markdown]
# * Completar la siguiente tabla
#
# |           	| data classification 	|
# |----------:	|--------------------:	|
# |      date 	|                     	|
# |      name 	|                     	|
# |     breed 	|                     	|
# | weight_kg 	|                     	|

# %% [markdown]
# * Generar un DataFrame con **el último registro de cada perro**.
#     * A priori, ¿qué resultado se obtiene *"droppeando"* filas sin argumentos?
#     * ¿Droppeando según la columna `name`?
#     * ¿Qué columna o combinación de columnas hace único el registro de un perro?
#     * ¿Qué ocurrencia debe conformar el DataFrame final?

# %% [markdown]
# ### Asincrónicos

# %% [markdown]
# * Dado el siguiente DataFrame en base a *una muestra* del dataset [pizza prices menu](https://www.kaggle.com/datasets/timmofeyy/-pizza-prices-menu-in-13-different-pizzerias):

# %%
pizza_menu = {
    "Food Name": {
        1: "Hand Tossed",
        2: "Hand Tossed",
        3: "Hand Tossed",
        4: "Handmade Pan",
        5: "Crunchy Thin Crust",
        6: "Crunchy Thin Crust",
        7: "Crunchy Thin Crust",
        8: "Brooklyn Style",
        9: "Brooklyn Style",
        10: "Gluten Free Crust",
        12: "Spinach & Feta (Hand Tossed or Thin Crust)",
        13: "Spinach & Feta (Hand Tossed, Handmade Pan or Thin Crust)",
        14: "Spinach & Feta (Hand Tossed, Thin Crust or Brooklyn Style)",
        15: "Spinach & Feta (Brooklyn Style)",
        16: "Spinach & Feta (Gluten Free Crust)",
        17: "Wisconsin 6 Cheese (Hand Tossed or Thin Crust)",
        18: "Wisconsin 6 Cheese (Hand Tossed, Handmade Pan or Thin Crust)",
        19: "Wisconsin 6 Cheese (Hand Tossed, Thin Crust or Brooklyn Style)",
        20: "Wisconsin 6 Cheese (Brooklyn Style)",
        21: "Wisconsin 6 Cheese (Gluten Free Crust)",
    },
    "Size": {
        1: 'Small (10")',
        2: 'Medium (12")',
        3: 'Large (14")',
        4: 'Medium (12")',
        5: 'Small (10")',
        6: 'Medium (12")',
        7: 'Large (14")',
        8: 'Large (14")',
        9: 'X-Large (16")',
        10: 'Small (10")',
        12: 'Small (10")',
        13: 'Medium (12")',
        14: 'Large (14")',
        15: 'X-Large (16")',
        16: 'Small (10")',
        17: 'Small (10")',
        18: 'Medium (12")',
        19: 'Large (14")',
        20: 'X-Large (16")',
        21: 'Small (10")',
    },
    "Price": {
        1: 5.99,
        2: 7.99,
        3: 9.99,
        4: 7.99,
        5: 5.99,
        6: 7.99,
        7: 9.99,
        8: 9.99,
        9: 11.99,
        10: 8.99,
        12: 11.99,
        13: 13.99,
        14: 15.99,
        15: 17.99,
        16: 14.99,
        17: 11.99,
        18: 13.99,
        19: 15.99,
        20: 17.99,
        21: 14.99,
    },
}

df = pd.DataFrame(pizza_menu)

df

# %% [markdown]
# * Corregir los nombres de columnas

# %% [markdown]
# * Generar una tabla con los column labels y su clasificación

# %% [markdown]
# * Generar *dos* DataFrames:
#     * Sólo un registro por tipo de pizza, el más barato.
#     * Sólo un registro por tipo de pizza, el más caro.

# %% [markdown]
# * Dado el siguiente DataFrame con datos de diputados de Rumania:

# %%
pd.read_html(
    "https://en.wikipedia.org/wiki/List_of_members_of_the_Chamber_of_Deputies_of_Romania_(2016%E2%80%932020)"
)[0]

# %% [markdown]
# * Corregir los nombres de columnas

# %% [markdown]
# * Generar una tabla con los column labels y su clasificación

# %% [markdown]
# * Generar un DataFrame con el último diputado por partido

# %% [markdown]
# ## is_null()
#
# Detecta datos faltantes en el DatFrame y devuelve un objeto similar con booleanos, donde `True` indica que en ese lugar hay un dato faltante.

# %% [markdown]
# ## NaN
#
# *Not a Number*. Cuando pandas no puede determinar un *valor numérico* para asignar a una entrada, le asigna `NaN`. Generalmente estos **NO AFECTAN** operaciones aritméticas.

# %% [markdown]
# ## is_na()
#
# Detecta NaN en el DatFrame y devuelve un objeto similar con booleanos, donde `True` indica que en ese lugar hay un NaN.

# %%
import numpy as np

real_state = {
    "        PID": {
        0: "        100001000",
        1: "        100002000",
        2: "        100003000",
        3: "        100004000",
        4: "        ",
        5: "        100006000",
        6: "        100007000",
        7: "        100008000",
        8: "        100009000",
    },
    "ST_NUM": {
        0: 104,
        1: 197,
        2: np.nan,
        3: 201,
        4: 203,
        5: 207,
        6: np.nan,
        7: 213,
        8: 215,
    },
    "ST_NAME": {
        0: "PUTNAM",
        1: "LEXINGTON",
        2: "LEXINGTON",
        3: "BERKELEY",
        4: "BERKELEY",
        5: "BERKELEY",
        6: "WASHINGTON",
        7: "TREMONT",
        8: "TREMONT",
    },
    "OWN_OCCUPIED": {
        0: "Y",
        1: "N",
        2: "N",
        3: "12",
        4: "Y",
        5: "Y",
        6: np.nan,
        7: "Y",
        8: "Y",
    },
    "NUM_BEDROOMS": {
        0: "3",
        1: "3",
        2: "-1",
        3: "1",
        4: "3",
        5: "NAN",
        6: "2",
        7: "--",
        8: "na",
    },
    "NUM_BATH": {
        0: "1",
        1: "1.5",
        2: "1",
        3: np.nan,
        4: "2",
        5: "1",
        6: "HURLEY",
        7: "1",
        8: "2",
    },
    "SQ_FT": {
        0: "1000",
        1: "--",
        2: "850",
        3: "700",
        4: "1600",
        5: "800",
        6: "950",
        7: np.nan,
        8: "1800",
    },
}

df = pd.DataFrame(real_state)

df

# %% [markdown]
# > ST_NUM: Street number
# > ST_NAME: Street name
# > OWN_OCCUPIED: Is the residence owner occupied
# > NUM_BEDROOMS: Number of bedrooms

# %% [markdown]
# * Corregir los nombres de columnas

# %% [markdown]
# ¿Cómo se clasifican los datos?
#
# * ST_NUM:
# * ST_NAME:
# * OWN_OCCUPIED:
# * NUM_BEDROOMS:

# %% [markdown]
# * Para cada columna, mostrar sus valores y una Serie booleana con `True` para aquellos valores que son null, combinar además `is_null()` y `sum()` para obtener un pequeño informe al respecto:

# %% [markdown]
# * Para la columna `NUM_BEDROOMS`, determinar el conjunto de valores no válidos que *deberían reemplazarse* por `NaN`.

# %% [markdown]
# * Usar el método `replace()` para convertir los mismos a `np.nan`

# %% [markdown]
# * Repetir el proceso con la columna `OWN_OCCUPIED`

# %% [markdown]
# ## fillna()
#
# Reemplaza NaN con un valor o método dados.

# %% [markdown]
# * Determinar un criterio y reemplazar los `NaN` de la columna

# %% [markdown]
# * Para el resto de las columnas:
#     * Determinar el conjunto de valores no válidos que deberían reemplazarse por NaN.
#     * Usar el método replace() para convertir los mismos a `np.nan`.
#     * Determinar un criterio y reemplazar los NaN de la columna.

# %% [markdown]
# * Realizar el proceso de inspección y limpieza de datos para un dataset de interés
